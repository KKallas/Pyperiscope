# %%
from pyperiscope import Scope
from pyperiscope import Scraper
import pyautogui

# %%
s=Scraper(pyautogui.screenshot())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
step = s.get_scope()

# %%
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGBA size=640x640>

# %%
step.find()
# Out:
# found: 1

# %%
step.save_string()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 step.save_string()
#
# File ~/Documents/Pyperiscope/src/pyperiscope/scope/layer3.py:12, in Scope.save_string(self)
#      11 def save_string(self):
# ---> 12     e = elvis()
#      13     e.leave(self.get_string())
#
# TypeError: elvis.__call__() missing 1 required positional argument: 'template'
