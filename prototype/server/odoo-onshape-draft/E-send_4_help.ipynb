# %%
import dill
import codecs
import pyautogui
import time
import pyperclip
import pyautogui
from pyperiscope import Scope

# %% [markdown]
# # 0. Open odoo tab
# If pyperiscope tab is active

# %%
# comment: Automated step generated with pyPeriscope V2 
payload = '''...'''
step = Scope(saved_dict=dill.loads(codecs.decode(payload.encode(), 'base64')))
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
try:
    step.find(confidence=0.99)
    window_found = True
except:
    window_found = False

# %%
if step.found_locations:
    pyautogui.click(step.get_locations()[0])
    pyautogui.hotkey('ctrl','t')
    time.sleep(0.5)
    pyautogui.write("https://mnemonic2.odoo.com/odoo/discuss?active_id=discuss.channel_2", interval=0.025)
    pyautogui.hotkey('enter')

# %% [markdown]
# # 1. Open odoo tab
# If other tabs is active but the pyperiscope is avaiable, if not give up

# %%
# comment: Automated step generated with pyPeriscope V2 
payload = '''...'''
step = Scope(saved_dict=dill.loads(codecs.decode(payload.encode(), 'base64')))
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
if window_found == False:
    step.find()
# Out:
# found: 1

# %%
if step.found_locations:
    pyautogui.click(step.get_locations()[0])
    pyautogui.hotkey('ctrl','t')
    time.sleep(0.5)
    pyautogui.write("https://mnemonic2.odoo.com/odoo/discuss?active_id=discuss.channel_2", interval=0.025)
    pyautogui.hotkey('enter')

# %% [markdown]
# # 2. Look for login
# if login is necessary, use chrome password manager

# %%
# comment: Automated step generated with pyPeriscope V2 
payload = '''...'''
step = Scope(saved_dict=dill.loads(codecs.decode(payload.encode(), 'base64')))
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
try:
    step.find()
except:
    pass

# %%
if step.found_locations:
    pyautogui.click(step.get_locations()[0])
    time.sleep(0.5)
    pyautogui.hotkey('down')
    time.sleep(0.5)
    pyautogui.hotkey('enter')
    time.sleep(0.5)
    pyautogui.hotkey('enter')

# %% [markdown]
# # 3. Post help plea into #mnemonic channel
# find the channel and click on it, type the help message

# %%
# comment: Automated step generated with pyPeriscope V2 
payload = '''...'''
step = Scope(saved_dict=dill.loads(codecs.decode(payload.encode(), 'base64')))
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
step.find(tries=5)
# Out:
# found: 1

# %%
import socket

def get_local_ip():
    s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
    try:
        s.connect(("8.8.8.8", 80))
        ip = s.getsockname()[0]
    finally:
        s.close()
    return ip
    
if step.found_locations:
    pyautogui.click(step.get_locations()[0]) # activate window if necessary
    time.sleep(0.5)
    pyautogui.write("Mnemonic workflow has stopped and needs your help", interval=0.01)
    pyautogui.hotkey('shift','enter')
    pyautogui.write("(http://"+get_local_ip()+":8888/lab/tree/Documents/git2/Pyperiscope/prototype/odoo-onshape-draft/run.ipynb)", interval=0.01)
    time.sleep(0.5)
    pyautogui.hotkey('enter')
    time.sleep(0.5)
    pyautogui.hotkey('ctrl','w')
