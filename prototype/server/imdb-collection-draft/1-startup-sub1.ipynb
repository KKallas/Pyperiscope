# %%
import dill
import codecs
import pyautogui
import time
import pyperclip
from pyperiscope import Scope

# %% [markdown]
# # 0. Open odoo products search dropdown
# Open the dropdown to select presaved search string

# %%
# comment: Automated step generated with pyPeriscope V2 
payload = '''...'''
step = Scope(saved_dict=dill.loads(codecs.decode(payload.encode(), 'base64')))
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
step.find()
# Out:
# found: 1

# %%
if step.found_locations:
    pyautogui.click(step.get_locations()[0])

# %% [markdown]
# # 1. Select the 1st option under the star
# use the 1st saved favovorite as default filter

# %%
# comment: Automated step generated with pyPeriscope V2 
payload = '''...'''
step = Scope(saved_dict=dill.loads(codecs.decode(payload.encode(), 'base64')))
step.render_preview()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
step.find()
# Out:
# found: 1

# %%
if step.found_locations:
    pyautogui.click(step.get_locations()[0])
    time.sleep(0.5)
    pyautogui.hotkey('esc')
